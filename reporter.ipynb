# %%
import json
import sys
sys.path.append('code')
import experiment

# %%
def report(path):
    metadata = json.load(open('experiments/lhd128-tn1-mtsentenceEmbedding-l20.0-mp0-lr0.01-hd128/meta.json'))
    for key in ['task_number', 'base_lr', 'l2_reg', 'mean_pool', 'hidden_dim', 'lstm_hidden_dim', 'wv_dimensions']:
        print key, ':', metadata[key]
    report_dir = 'experiments/' + path
    experiment.report(report_dir + '/history.cpkl')

# %%
report('lhd128-tn1-mtsentenceEmbedding-l20.0-mp0-lr0.01-hd128')
report('lhd128-tn1-mtsentenceEmbedding-l20.001-mp1-lr0.1-hd128')
# Out:
# task_number : 1
# base_lr : 0.01
# l2_reg : 0.0
# mean_pool : 0
# hidden_dim : 128
# lstm_hidden_dim : 128
# wv_dimensions : 50
# task_number : 1
# base_lr : 0.01
# l2_reg : 0.0
# mean_pool : 0
# hidden_dim : 128
# lstm_hidden_dim : 128
# wv_dimensions : 50
